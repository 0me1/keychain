# %%
from pydantic import BaseModel

class ten(BaseModel):
    p:str


A = [ten(p="1"),ten(p="2"),ten(p="3"),ten(p="4")]

print(A.index(ten(p="2")))
# Out:
# {<__main__.CardItem at 0x1e3d93f0e10>,
# ...
#  <__main__.CardItem at 0x1e3d93f4ec0>}
